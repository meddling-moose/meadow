# %%
import pandas as pd
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np

# %%
#construct path to csv
vinyl_data = Path('resources/final_record_collection_mk2.csv')

vinyl_df = pd.read_csv(vinyl_data)
vinyl_df.head()
# Out:
#         Artist                    Album    Year      Genre  Price  \
# 0  .38 Special  WIld-Eyed Southern Boys  1980.0       Rock    5.0
# 1  .38 Special           Special Forces  1982.0       Rock    4.0
# 2  .38 Special            Tour De Force  1983.0       Rock    5.0
# 3      100gecs                1000 gecs  2019.0  Hyper Pop   24.0
# 4         2Pac       2Pac Greatest Hits  1998.0        Rap   70.0
#
#   Date Purchased                              Refined ChatGPT Genre  \
# 0            NaN      ['Southern Rock', 'Arena Rock', 'Blues Rock']
# 1            NaN      ['Southern Rock', 'Arena Rock', 'Blues Rock']
# 2            NaN      ['Southern Rock', 'Arena Rock', 'Blues Rock']
# 3            NaN  ['Experimental Electronic', 'Electropop', 'Gli...
# 4     10/28/2023  ['West Coast Hip Hop', 'Gangsta Rap', 'Politic...
#
#                Sub_Genre_1  Sub_Genre_2    Sub_Genre_3
# 0            Southern Rock   Arena Rock     Blues Rock
# 1            Southern Rock   Arena Rock     Blues Rock
# 2            Southern Rock   Arena Rock     Blues Rock
# 3  Experimental Electronic   Electropop     Glitch Pop
# 4       West Coast Hip Hop  Gangsta Rap  Political Rap

# %%
vinyl_df.columns
# Out:
# Index(['Artist', 'Album', 'Year', 'Genre', 'Price', 'Date Purchased',
#        'Refined ChatGPT Genre', 'Sub_Genre_1', 'Sub_Genre_2', 'Sub_Genre_3'],
#       dtype='object')

# %%
vinyl_df.dtypes
# Out:
# Artist                    object
# Album                     object
# Year                     float64
# Genre                     object
# Price                    float64
# Date Purchased            object
# Refined ChatGPT Genre     object
# Sub_Genre_1               object
# Sub_Genre_2               object
# Sub_Genre_3               object
# dtype: object

# %%
grouped_by_genre = vinyl_df.groupby("Genre")
grouped_by_genre["Album"].count()
# Out:
# Genre
# Afrobeat             2
# Alternative          8
# Alternative Rock    40
# Ambient              1
# Ambient Jazz         1
#                     ..
# Surf Rock            1
# Synth Pop            2
# Techno               1
# Thrash Metal         3
# Zam Rock             1
# Name: Album, Length: 87, dtype: int64

# %%
#Get a list of genres
genres = list(vinyl_df["Genre"].unique())
print(genres)
# Out:
# ['Rock', 'Hyper Pop', 'Rap', 'House', 'Hip Hop', 'Soul', 'Pop', 'Hard Rock', 'Jazz', 'Prog Rock', 'Folk Rock', 'Alternative Rock', 'Indie', 'R&B', 'Disco', 'Soundtrack', 'City Pop', 'Alternative', 'Bossa Nova', 'Punk', 'Country', 'Funk', 'Pop Rock', 'Blues', 'Reggae', 'Discoid Funk', 'Afrobeat', 'Jungle', 'Electronic', 'Pscyhadelic Rock', 'Hair Metal', 'Pschadelic Rock', 'New Wave', 'Dance Pop', 'Nu Metal', 'Folk', 'Punk Rock', 'Metal', 'J-Pop', 'Ambient Jazz', 'Boogie', 'Jai Wave', 'Hip-Hop', 'Progressive Rock', 'Pscyhadelic Folk', 'Country Rock', 'Post-Punk', 'Heavy Metal', 'Indie Pop', 'Psychadelia', 'Soul Jazz', 'Rock and Roll', 'American Folk', 'Indie Folk', 'Southern Rock', 'Synth Pop', 'Psychadelic Jazz', 'Soft Rock', 'Thrash Metal', 'Reggae Fusion', 'Indie Rock', 'Progressive', 'Emo', 'Chamber Folk', 'Lofi Hip Hop', 'Future Bass', 'Ambient', 'Rap Rock', 'Arena Rock', 'Zam Rock', 'Dub', 'Modern Soul', 'Deep House', 'Jazz Funk', 'Modern City Pop', 'Latin Rock', 'Jazz Rock', 'Blues Rock', 'Glam Rock', 'Art Rock', 'Psychedelic Rock', 'Flamenco', 'Surf Rock', 'Mardi-Gras Funk', 'Compilation', 'Techno', 'Neo Angsty Rock']

# %%
#Get list of counts that matches each genre
counts = vinyl_df.groupby("Genre").size()
print(counts)
print("Count of all items:", counts.sum())
# Out:
# Genre
# Afrobeat             2
# Alternative          8
# Alternative Rock    40
# Ambient              1
# Ambient Jazz         1
#                     ..
# Surf Rock            1
# Synth Pop            2
# Techno               1
# Thrash Metal         3
# Zam Rock             1
# Length: 87, dtype: int64
# count of all items: 694

# %%
plt.title("Count of Albums of Each Genre")
plt.barh(genres, counts, color='r', align='center')
# Out:
# <BarContainer object of 87 artists>

# %%
#Sort this such that the most is at the top
